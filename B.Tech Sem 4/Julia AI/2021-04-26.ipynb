# %%
import Pkg
Pkg.add("DataFrames")
Pkg.add("CSV")
Pkg.add("Plots")
Pkg.add("Lathe")
Pkg.add("GLM")
Pkg.add("Statistics")
Pkg.add("StatsPlots")
Pkg.add("MLBase")
Pkg.add("ClassImbalance")
Pkg.add("ROCAnalysis")
Pkg.add("StatsBase")
Pkg.add("Pandas")
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1317
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1317
# ArgumentError: Package ClassImbalance not found in current path:
# - Run `import Pkg; Pkg.add("ClassImbalance")` to install the ClassImbalance package.
#
#
# Stacktrace:
#  [1] require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:871
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
using Pkg
using DataFrames
using CSV
using Plots
using Lathe
using GLM
using Statistics
using StatsPlots
using MLBase
using ClassImbalance
using ROCAnalysis
using StatsBase
using Pandas

# %%
df = DataFrame(CSV.File("./res/data.csv"))
first(df,5)
# Out:
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 2. Filling remaining columns with `missing`
# └ @ CSV C:\Users\harsh\.julia\packages\CSV\CJfFO\src\file.jl:605
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 3. Filling remaining columns with `missing`
# └ @ CSV C:\Users\harsh\.julia\packages\CSV\CJfFO\src\file.jl:605
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 4. Filling remaining columns with `missing`
# └ @ CSV C:\Users\harsh\.julia\packages\CSV\CJfFO\src\file.jl:605
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 5. Filling remaining columns with `missing`
# └ @ CSV C:\Users\harsh\.julia\packages\CSV\CJfFO\src\file.jl:605
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 6. Filling remaining columns with `missing`
# └ @ CSV C:\Users\harsh\.julia\packages\CSV\CJfFO\src\file.jl:605
# ...

# %%
data = get_dummies(df, "diagnosis")
# Out:
# UndefVarError: get_dummies not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[14]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094
